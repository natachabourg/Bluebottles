# %%
# %reset
from parcels import (FieldSet, AdvectionRK4, BrownianMotion2D, plotTrajectoriesFile, Field,
                     ParticleSet, JITParticle, Variable, ErrorCode)
import numpy as np
import scipy as sc
import math
from datetime import timedelta, datetime
from operator import attrgetter
import copy_plottrajectoriesfile as cpt
import matplotlib.animation as animation
import imageio #to make .gif out of multiple .png
import matplotlib.pyplot as plt
import scipy.io as sio #to load matlab file
import xarray as xr
"""
Load IMOS raw data
"""
#filenames = "../raw_imos_current_data/IMOS_OceanCurrent_HV_2019_C-20190520T232835Z.nc"
filenames = "../raw_imos_current_data/IMOS_OceanCurrent_HV_2018.nc"
dataset=xr.open_dataset(filenames)


"""
Create fieldset with imos raw data
"""

variables = {'U' : 'UCUR',
                'V' : 'VCUR'}
dimensions = {'lat' : 'LATITUDE',
                  'lon' : 'LONGITUDE',
                  'time' : 'TIME'} 

fieldset_imos = FieldSet.from_xarray_dataset(dataset, variables, dimensions, allow_time_extrapolation=True, deferred_load=False)
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# ERROR:root:Invalid alias: The name clear can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name more can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name less can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name man can't be aliased because it is another magic command.
# WARNING: Casting depth data to np.float32
# WARNING:parcels.tools.loggers:Casting depth data to np.float32

# %%
"""
Change U and V shape (could be optimized)
"""

i_lat_min=list(fieldset_imos.U.lat).index(-36)
i_lat_max=list(fieldset_imos.U.lat).index(-24)+1

i_lon_min=list(fieldset_imos.U.lon).index(150)
i_lon_max=list(fieldset_imos.U.lon).index(160)+1

lati=fieldset_imos.U.lat[i_lat_min:i_lat_max]
longi=fieldset_imos.U.lon[i_lon_min:i_lon_max]
ucur=fieldset_imos.U.data
vcur=fieldset_imos.V.data
u_imos=[]
v_imos=[]
grid_imos=[[],[]]
grid_lat=[]
grid_lon=[]

for i in range(len(lati)): #Create grid of IMOS latitude longitude
    for j in range(len(longi)):
        grid_imos[0].append(lati[i])
        grid_imos[1].append(longi[j]) 
grid_imos=np.asarray(grid_imos).T

for t in range(len(dataset['TIME'])): #for every time step
    values_u=[]
    values_v=[]
    for i in range(i_lat_min,i_lat_max): #take U and V for every couple (lati,longi)
        for j in range(i_lon_min,i_lon_max):
            values_u.append(ucur[t,i,j])
            values_v.append(vcur[t,i,j])
    u_imos.append(np.asarray(values_u))
    v_imos.append(np.asarray(values_v))

"""
Create grid for extrapolated data #(resolution 0.1 degree)
"""
grid_lat_ext,grid_lon_ext = np.mgrid[-36:-24:0.1, 150:160:0.1] 
grid_ext=(grid_lat_ext,grid_lon_ext)

# %%
"""
Extrapolate U and V data from grid_imos to grid_exp for each time step (could be optimized)
"""

u_ext=[[] for i in range(len(u_imos))]
v_ext=[[] for i in range(len(v_imos))]
for i in range(len(u_imos)):
    u_ext[i] = sc.interpolate.griddata(grid_imos, u_imos[i], grid_ext, method='linear')
    v_ext[i] = sc.interpolate.griddata(grid_imos, v_imos[i], grid_ext, method='linear')

# %%
"""
time_imos float to datetime object
"""
time_imos=dataset['TIME'].data

# %%
ds_ext.time
# Out:
# -----------------------------------------------------------------------
# NameError                             Traceback (most recent call last)
# <ipython-input-5-2a5ba28ceb40> in <module>
# ----> 1 ds_ext.time
#
# NameError: name 'ds_ext' is not defined

# %%
"""
Put extrapolated data in a dataset
"""

import xarray as xr
u=xr.DataArray(u_ext,
                dims=['time','lat','lon'],
                coords={'time':time_imos,
                        'lat':np.arange(-36,-24,0.1),
                        'lon':np.arange(150,160,0.1)},)     

v=xr.DataArray(v_ext,
                dims=['time','lat','lon'],
                coords={'time':time_imos,
                        'lat':np.arange(-36,-24,0.1),
                        'lon':np.arange(150,160,0.1)},)   

ds_ext=u.to_dataset(name='u_cur')
ds_ext['v_cur']=v

# %%
"""
Create mask
"""

mask_ocean = 2 * np.ones((ds_ext.dims['lat'], ds_ext.dims['lon'])) * np.isfinite(ds_ext.u_cur.isel(time=0))  
mask_land = 1 * np.ones((ds_ext.dims['lat'], ds_ext.dims['lon'])) * (ds_ext.u_cur.isel(time=0)==0.)
mask_array = mask_land + mask_ocean 
mask_array.plot()

ds_ext.coords['MASK'] = (('lat', 'lon'), mask_array) 
ds_ext['u_cur_masked']=ds_ext['u_cur'].where(ds_ext.MASK==2)
ds_ext['v_cur_masked']=ds_ext['v_cur'].where(ds_ext.MASK==2)

# %%
"""
Create wind dataset
"""
u_wind_dataset = xr.open_dataset('../raw_imos_current_data/barra_R_uwnd10m_2016_2019.nc')
v_wind_dataset = xr.open_dataset('../raw_imos_current_data/barra_R_vwnd10m_2016_2019.nc')

u_wind=xr.DataArray(u_wind_dataset['uwnd10m'].data,
                dims=['time','lat','lon'],
                coords={'time':u_wind_dataset['time'].data,
                        'lat':u_wind_dataset['latitude'].data,
                        'lon':u_wind_dataset['longitude'].data},)     

v_wind=xr.DataArray(v_wind_dataset['vwnd10m'].data,
                dims=['time','lat','lon'],
                coords={'time':v_wind_dataset['time'].data,
                        'lat':u_wind_dataset['latitude'].data, #SALE 
                        'lon':u_wind_dataset['longitude'].data},)  

#add to the existing dataset
wind_dataset=u_wind.to_dataset(name='u_wind')
wind_dataset['v_wind']=v_wind

# %%
wind_dataset['time'][4610].data
# Out:
# numpy.datetime64('2019-02-26T18:00:00.000000000')

# %%
"""
Create fieldset with  wind data
"""

variables = {'U_wind':'u_wind',
            'V_wind':'v_wind'}
dimensions = {'lon' : 'lon',
              'lat' : 'lat',
              'time' : 'time'} 

fieldset_wind = FieldSet.from_xarray_dataset(wind_dataset, variables, dimensions, allow_time_extrapolation=True)

# %%
"""
Create brownian motion coefficient data
"""
size3D=(len(ds_ext['time']),len(ds_ext['lat']),len(ds_ext['lon']))
kh_coeff=26.5 #coefficient of oceanic diffusion m^2.sec^-1
values_kh= kh_coeff*np.ones(size3D)

kh_zonal=xr.DataArray(values_kh,
                dims=['time','lat','lon'],
                coords={'time':time_imos,
                        'lat':np.arange(-36,-24,0.1),
                        'lon':np.arange(150,160,0.1)},)     

kh_meridional=xr.DataArray(values_kh,
                dims=['time','lat','lon'],
                coords={'time':time_imos,
                        'lat':np.arange(-36,-24,0.1),
                        'lon':np.arange(150,160,0.1)},)  

#add to the existing dataset
ds_ext['kh_zonal']=kh_zonal
ds_ext['kh_meridional']=kh_meridional

#Mask data on land
ds_ext['kh_zonal']=ds_ext['kh_zonal'].where(ds_ext.MASK==2)
ds_ext['kh_meridional']=ds_ext['kh_meridional'].where(ds_ext.MASK==2)

# %%
"""
Create fieldset with extrapolated cur data, wind data, brownian motion
"""

variables = {'U' : 'u_cur_masked', #U refers to U_cur bc AdvectionRK4 needs U
            'V' : 'v_cur_masked',
            'Kh_zonal' : 'kh_zonal',
            'Kh_meridional' : 'kh_meridional'}
dimensions = {'lon' : 'lon',
              'lat' : 'lat',
              'time' : 'time'} 

fieldset = FieldSet.from_xarray_dataset(ds_ext, variables, dimensions, allow_time_extrapolation=True)
# Out:
# WARNING: Casting lon data to np.float32
# WARNING:parcels.tools.loggers:Casting lon data to np.float32
# WARNING: Casting lat data to np.float32
# WARNING:parcels.tools.loggers:Casting lat data to np.float32

# %%
fieldset.add_field(fieldset_wind.U_wind)
fieldset.add_field(fieldset_wind.V_wind)

# %%
from parcels import (FieldSet, AdvectionRK4, BrownianMotion2D, plotTrajectoriesFile, Field,
                     ParticleSet, JITParticle, Variable, ErrorCode)

# %%
def LimitBoundaries(lon_i, lat_i, lon_min): #return lon and lat for every lon>lon_min
    newlat=[]
    newlon=[]
    for i in range (0,len(lat_i)):
        if (lon_i[i]>lon_min):
            newlat.append(lat_i[i])
            newlon.append(lon_i[i])
    return newlon, newlat



"""Load & read Matlab file
mat_boundaries = sio.loadmat('../../nsw_boundaries/raw_nsw_boundaries/NSW_boundary.mat')
lat_nsw=mat_boundaries['lat_nsw'][0]
lon_nsw=mat_boundaries['lon_nsw'][0]
lon_nsw, lat_nsw = LimitBoundaries(lon_nsw, lat_nsw, 149.5)
"""
#plt.plot(lon_nsw, lat_nsw)
#plt.show()
# Out:
# "Load & read Matlab file\nmat_boundaries = sio.loadmat('../../nsw_boundaries/raw_nsw_boundaries/NSW_boundary.mat')\nlat_nsw=mat_boundaries['lat_nsw'][0]\nlon_nsw=mat_boundaries['lon_nsw'][0]\nlon_nsw, lat_nsw = LimitBoundaries(lon_nsw, lat_nsw, 149.5)\n"

# %%
"""
Compare before and after data extrapolation
"""

#fieldset_imos.U.show(domain={'N':-24, 'S':-36, 'E':160, 'W':150},land=False)
#fieldset.U.show(land=False)

def cart2pol(x, y):
    """
    author : Dr. Schaeffer
    return rho in m/s and phi in radian in oceano conv
    """
    
    rho = math.sqrt(x**2 + y**2)
    phi = np.arctan2(y, x)
    return(rho, phi)

# %%
"""
Dataset for a time fixed to plot trajectories with U field
"""
ds_ext.isel(time=0).to_netcdf('dataset.nc')

# %%
# %matplotlib qt
import math

def DeleteParticle(particle, fieldset, time):
    particle.delete()

seed = sio.loadmat('polygons_files/seeds.mat')
seed_lons = seed['seedlon'][0]
seed_lats = seed['seedlat'][0]

# %%
"""
lons = [151.5, 152, 152.5, 153, 153.5, 154, 154.5, 154.5, 154.5, 154.5, 154.5, 154.5, 154.5, 154.5, 154, 153.5, 153.0, 152.5, 152]
lats = [-34.5, -34.5, -34.5, -34.5, -34.5, -34.5, -34.3, -34.1, -33.9, -33.7, -33.5, -33.3, -33.1, -33, -33, -33, -33, -33, -33]

pset = ParticleSet.from_list(fieldset=fieldset,
                             lon=seed_lons,
                             lat=seed_lats,
                             time = time_imos[0],
                             repeatdt=timedelta(days=1),
                             pclass = JITParticle)
"""
#pset.show(field=fieldset.U,land=False)
#repeatdt=timedelta(days=1),
# Out:
# '\nlons = [151.5, 152, 152.5, 153, 153.5, 154, 154.5, 154.5, 154.5, 154.5, 154.5, 154.5, 154.5, 154.5, 154, 153.5, 153.0, 152.5, 152]\nlats = [-34.5, -34.5, -34.5, -34.5, -34.5, -34.5, -34.3, -34.1, -33.9, -33.7, -33.5, -33.3, -33.1, -33, -33, -33, -33, -33, -33]\n\npset = ParticleSet.from_list(fieldset=fieldset,\n                             lon=seed_lons,\n                             lat=seed_lats,\n                             time = time_imos[0],\n                             repeatdt=timedelta(days=1),\n                             pclass = JITParticle)\n'

# %%
class degparticle(JITParticle):deg = Variable('deg', initial=0)

def sampledeg(particle, fieldset, time):
    """
    1 particle out of 2 will go to the left, the other to the right
    """
    
    if particle.id % 2 == 0:
        particle.deg = -40*math.pi/180
    else : 
        particle.deg = 40*math.pi/180

# %%
"""
Check if angles are evenly distributed
"""
# %matplotlib inline
plt.figure()
for i in range(len(pset)):
    if pset[i].id % 2 == 0: #even
        plt.scatter(pset[i].lon,pset[i].lat,color='b')
    else:
        plt.scatter(pset[i].lon,pset[i].lat,color='r')

plt.show()

# %%
"""
Check if angles are evenly distributed
"""
# %matplotlib inline
plt.figure()
for i in range(len(pset)):
    if pset[i].id % 2 == 0: #even
        plt.scatter(pset[i].lon,pset[i].lat,color='b')
    else:
        plt.scatter(pset[i].lon,pset[i].lat,color='r')

plt.show()

# %%
import math #bc kernel cant handle numpy
def WindDrag(particle, fieldset, time):

    #constants
    S_x = 1.12e-4 #m^2 (from Daniel Lee)
    S_y = 5.5e-4 #m^2 (from Daniel Lee)
    S_w = 3.78e-4 #m^2 (from Daniel Lee)
    rho_a = 1.225 #kg.m^-3
    rho_w = 1030 #kg.m^-3
    
    #variables
    C_ax = 0.1
    C_ay = 1
    C_w = 1
    gamma = particle.deg
    
    
    u_wind = fieldset.U_wind[time, particle.depth, particle.lat, particle.lon]
    v_wind = fieldset.V_wind[time, particle.depth, particle.lat, particle.lon]

    coeff = (math.sqrt((S_x*C_ax)**2+ (S_y*C_ay)**2))/(S_w*C_w)
    vel_wind = math.sqrt((u_wind)**2 + (v_wind)**2)
    dir_wind = math.atan2(u_wind,v_wind) 
    vel_bb = math.fabs(vel_wind)*math.sqrt(rho_a/rho_w*coeff)
    
    theta = dir_wind + gamma #wind_dir in oceano, gamma : angle between wind course and BB course
    
    diff_x += (math.sin(theta)*vel_bb)*particle.dt #in meters
    diff_y += (math.cos(theta)*vel_bb)*particle.dt #in meters
    
    particle.lon += diff_x/(1852*60*math.cos(particle.lat*math.pi/180)) #meters to degree
    particle.lat += diff_y/(1852*60*math.cos(particle.lat*math.pi/180)) #meters to degree

# %%
pset = ParticleSet.from_list(fieldset=fieldset,
                             lon=seed_lons,
                             lat=seed_lats,
                             time = wind_dataset['time'][3051].data,
                             repeatdt=timedelta(hours=24),
                             pclass = degparticle)

# %%
kernels = pset.Kernel(AdvectionRK4)+pset.Kernel(sampledeg)+pset.Kernel(WindDrag)+pset.Kernel(BrownianMotion2D)

pset.execute(kernels, 
             runtime = timedelta(days = 11), 
             dt = timedelta(hours = 1), #toutes les heures
             recovery = {ErrorCode.ErrorOutOfBounds: DeleteParticle},
             output_file = pset.ParticleFile(name = 'nc_trajectory_files/18_random_cay1.nc', outputdt = timedelta(days = 1)))
# Out:
# INFO: Compiled degparticleAdvectionRK4sampledegWindDragBrownianMotion2D ==> /tmp/parcels-13529592/ff8ccbd16eb622378be8ed2a81f33f21.so
# INFO:parcels.tools.loggers:Compiled degparticleAdvectionRK4sampledegWindDragBrownianMotion2D ==> /tmp/parcels-13529592/ff8ccbd16eb622378be8ed2a81f33f21.so
# 100% (950400.0 of 950400.0) |############| Elapsed Time: 0:00:04 Time:  0:00:04

# %%
pset = ParticleSet.from_list(fieldset=fieldset,
                             lon=seed_lons,
                             lat=seed_lats,
                             time = time_imos[0],
                             pclass = JITParticle)

# %%
fieldset.U.dimensions
# Out:
# {'lon': 'lon', 'lat': 'lat', 'time': 'time'}

# %%
wind_dataset['time'][3051]
# Out:
# <xarray.DataArray 'time' ()>
# array('2018-02-02T00:00:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 2018-02-02

# %%
import numpy as np
import scipy as sc
import math
from datetime import timedelta, datetime
from operator import attrgetter
import copy_plottrajectoriesfile as cpt
import matplotlib.animation as animation
import imageio #to make .gif out of multiple .png
import matplotlib.pyplot as plt
import scipy.io as sio #to load matlab file
import xarray as xr
from shapely.geometry import Point, Polygon
from astropy.io import ascii
from astropy.table import Table, Column

# %%
"""
Load polygons of beaching
"""

boundaries_poly = sio.loadmat('polygons_files/polygons_beaching.mat')

# %%
"""
Extract lon lat of polygon n5
"""

lon_poly = boundaries_poly['lon_pol5'][0]
lat_poly = boundaries_poly['lat_pol5'][0]

# %%
"""
Create polygon from lat/lon
"""

coords_poly = [(lat_poly[i],lon_poly[i]) for i in range(0,len(lon_poly))]
poly = Polygon(coords_poly)
poly

# %%
latitude = np.asarray(file['lat']).reshape(len(file['lat']),len(file['lat'][0]),1)
longitude = np.asarray(file['lon']).reshape(len(file['lon']),len(file['lon'][0]),1)

coords = [np.hstack((latitude[i],longitude[i])) for i in range(len(file['lat']))]
p = [[Point(coords[i][j]) for j in range(len(file['lat'][i]))] for i in range(len(file['lat']))]

# %%
"""
Save time, lon, lat and number of the beached particles
"""

particle_beached, time_beached, lat_beached, lon_beached, deg_beached = [], [], [], [], []

for i in range(0,len(file['lat'])):
    for j in range(0,len(file['lat'][i])):
        if p[i][j].within(poly):
            particle_beached.append(i)
            time_beached.append(file['time'][i][j].data)
            lat_beached.append(file['lat'][i][j].data)
            lon_beached.append(file['lon'][i][j].data)
            #deg_beached.append(file['deg'][i][j].data)
            break
beaching_table = Table([time_beached, particle_beached, lat_beached, lon_beached], names = ('time','particle #','lat','lon'))
ascii.write(beaching_table, 'results_beaching/18_random_cay1.csv', format='csv', fast_writer=False, overwrite=True)

# %%
import pandas as pd
# %matplotlib inline
random_all18=pd.read_csv('results_beaching/18_random_cay1.csv')
random_all18['time']=random_all18['time'].astype("datetime64")
random_all18['time'].groupby(random_all18["time"].dt.month).count().plot(kind="bar")

# %%
fieldset.U_wind.dimensions[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-ed699a87bec3> in <module>
# ----> 1 fieldset.U_wind.dimensions[0]
#
# KeyError: 0

# %%
whos
# Out:
# Variable               Type           Data/Info
# -----------------------------------------------
# AdvectionRK4           function       <function AdvectionRK4 at 0x7f9eac00bd08>
# BrownianMotion2D       function       <function BrownianMotion2D at 0x7f9eac00d048>
# DeleteParticle         function       <function DeleteParticle at 0x7f9e77e171e0>
# ErrorCode              EnumMeta       <enum 'ErrorCode'>
# Field                  type           <class 'parcels.field.Field'>
# FieldSet               type           <class 'parcels.fieldset.FieldSet'>
# JITParticle            type           <class 'parcels.particle.JITParticle'>
# ParticleSet            type           <class 'parcels.particleset.ParticleSet'>
# Variable               type           <class 'parcels.particle.Variable'>
# WindDrag               function       <function WindDrag at 0x7f9e803e48c8>
# animation              module         <module 'matplotlib.anima<...>matplotlib/animation.py'>
# attrgetter             type           <class 'operator.attrgetter'>
# cpt                    module         <module 'copy_plottraject<...>plottrajectoriesfile.py'>
# dataset                Dataset        <xarray.Dataset>\nDimensi<...>.aodn.org.au/oceancurrent
# datetime               type           <class 'datetime.datetime'>
# degparticle            type           <class '__main__.degparticle'>
# dimensions             dict           n=3
# ds_ext                 Dataset        <xarray.Dataset>\nDimensi<...>5 26.5 ... 26.5 26.5 26.5
# fieldset               FieldSet       <parcels.fieldset.FieldSe<...>object at 0x7f9e68cc6518>
# fieldset_imos          FieldSet       <parcels.fieldset.FieldSe<...>object at 0x7f9e69dd0d30>
# fieldset_wind          FieldSet       <parcels.fieldset.FieldSe<...>object at 0x7f9e6b7a99e8>
# filenames              str            ../raw_imos_current_data/<...>S_OceanCurrent_HV_2018.nc
# grid_ext               tuple          n=2
# grid_imos              ndarray        3111x2: 6222 elems, type `float32`, 24888 bytes
# grid_lat               list           n=0
# grid_lat_ext           ndarray        120x100: 12000 elems, type `float64`, 96000 bytes
# grid_lon               list           n=0
# grid_lon_ext           ndarray        120x100: 12000 elems, type `float64`, 96000 bytes
# i                      int            361
# i_lat_max              int            181
# i_lat_min              int            120
# i_lon_max              int            516
# i_lon_min              int            465
# imageio                module         <module 'imageio' from '/<...>ges/imageio/__init__.py'>
# j                      int            515
# kernels                Kernel         <parcels.kernel.Kernel object at 0x7f9e6950a550>
# kh_coeff               float          26.5
# kh_meridional          DataArray      <xarray.DataArray (time: <...>. 159.6 159.7 159.8 159.9
# kh_zonal               DataArray      <xarray.DataArray (time: <...>. 159.6 159.7 159.8 159.9
# lati                   ndarray        61: 61 elems, type `float32`, 244 bytes
# longi                  ndarray        51: 51 elems, type `float32`, 204 bytes
# mask_array             DataArray      <xarray.DataArray 'u_cur'<...>. 159.6 159.7 159.8 159.9
# mask_land              DataArray      <xarray.DataArray 'u_cur'<...>. 159.6 159.7 159.8 159.9
# mask_ocean             DataArray      <xarray.DataArray 'u_cur'<...>. 159.6 159.7 159.8 159.9
# math                   module         <module 'math' from '/hom<...>37m-x86_64-linux-gnu.so'>
# np                     module         <module 'numpy' from '/ho<...>kages/numpy/__init__.py'>
# pd                     module         <module 'pandas' from '/h<...>ages/pandas/__init__.py'>
# plotTrajectoriesFile   function       <function plotTrajectoriesFile at 0x7f9eab2092f0>
# plt                    module         <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# pset                   ParticleSet    P[21243](lon=150.519089, <...>0000, time=950400.000000)
# random_all18           DataFrame                 time  particle<...>\n[6383 rows x 4 columns]
# sampledeg              function       <function sampledeg at 0x7f9e803e4d90>
# sc                     module         <module 'scipy' from '/ho<...>kages/scipy/__init__.py'>
# seed                   dict           n=7
# seed_lats              ndarray        219: 219 elems, type `float64`, 1752 bytes
# seed_lons              ndarray        219: 219 elems, type `float64`, 1752 bytes
# sio                    module         <module 'scipy.io' from '<...>es/scipy/io/__init__.py'>
# size3D                 tuple          n=3
# t                      int            361
# time_imos              ndarray        362: 362 elems, type `datetime64[ns]`, 2896 bytes
# timedelta              type           <class 'datetime.timedelta'>
# u                      DataArray      <xarray.DataArray (time: <...>. 159.6 159.7 159.8 159.9
# u_ext                  list           n=362
# u_imos                 list           n=362
# u_wind                 DataArray      <xarray.DataArray (time: <...>. 159.82 159.93 160.04001
# u_wind_dataset         Dataset        <xarray.Dataset>\nDimensi<...>mp_thread_number:       1
# ucur                   ndarray        362x351x641: 81446742 elems, type `float32`, 325786968 bytes (310.69466400146484 Mb)
# v                      DataArray      <xarray.DataArray (time: <...>. 159.6 159.7 159.8 159.9
# v_ext                  list           n=362
# v_imos                 list           n=362
# v_wind                 DataArray      <xarray.DataArray (time: <...>. 159.875 159.985 160.095
# v_wind_dataset         Dataset        <xarray.Dataset>\nDimensi<...>mp_thread_number:       1
# values_kh              ndarray        362x120x100: 4344000 elems, type `float64`, 34752000 bytes (33.14208984375 Mb)
# values_u               list           n=3111
# values_v               list           n=3111
# variables              dict           n=4
# vcur                   ndarray        362x351x641: 81446742 elems, type `float32`, 325786968 bytes (310.69466400146484 Mb)
# wind_dataset           Dataset        <xarray.Dataset>\nDimensi<...>n nan ... nan nan nan nan
# xr                     module         <module 'xarray' from '/h<...>ages/xarray/__init__.py'>

# %%
def WindDragQueen(particle, fieldset, time):
    
    Cd = 0.1
    gamma = particle.deg
    
    u_wind = fieldset.U_wind[time, particle.depth, particle.lat, particle.lon]
    v_wind = fieldset.V_wind[time, particle.depth, particle.lat, particle.lon]


    vel_wind = math.sqrt((u_wind)**2 + (v_wind)**2)
    dir_wind = math.atan2(u_wind,v_wind) 
    
    vel_bb = Cd*vel_wind
    
    theta = dir_wind + gamma #wind_dir in oceano, gamma : angle between wind course and BB course
    
    diff_x += (math.sin(theta)*vel_bb)*particle.dt #in meters
    diff_y += (math.cos(theta)*vel_bb)*particle.dt #in meters
    
    particle.lon += diff_x/(1852*60*math.cos(particle.lat*math.pi/180)) #meters to degree
    particle.lat += diff_y/(1852*60*math.cos(particle.lat*math.pi/180)) #meters to degree

# %%
# %matplotlib qt

# %%
plotTrajectoriesFile('nc_trajectory_files/01_18_40deg_cay1.nc',
                     tracerfile='dataset.nc',
                     tracerlon='lon',
                     tracerlat='lat',
                     tracerfield='v_cur_masked');

# %%
plotTrajectoriesFile('nc_trajectory_files/yooo.nc',
                     tracerfile='dataset.nc',
                     tracerlon='lon',
                     tracerlat='lat',
                     tracerfield='v_cur_masked');

# %%
plotTrajectoriesFile('nc_trajectory_files/trrajectory.nc', mode='movie2d_notebook')
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
plotTrajectoriesFile('nc_trajectory_files/trrajectory.nc', mode='movie2d_notebook')
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
plotTrajectoriesFile('nc_trajectory_files/trajectory.nc', mode='hist2d')
# Out:
# <module 'matplotlib.pyplot' from '/home/z3529592/anaconda3/envs/py3_parcels/lib/python3.7/site-packages/matplotlib/pyplot.py'>
